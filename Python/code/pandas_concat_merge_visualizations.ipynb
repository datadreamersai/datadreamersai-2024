# %%
import pandas as pd

# %%
courses = pd.read_csv('/content/courses.csv')
students = pd.read_csv('/content/students.csv')
jan_reg = pd.read_csv('/content/reg-month1.csv')
feb_reg = pd.read_excel('/content/reg-month2.xlsx')

# %%
courses.head()
# Out:
#    course_id       course_name  price
# 0          1            python   2499
# 1          2               sql   3499
# 2          3     data analysis   4999
# 3          4  machine learning   9999
# 4          5           tableau   2499

# %%
students.head()
# Out:
#    student_id            name  partner
# 0           1   Kailash Harjo       23
# 1           2     Esha Butala        1
# 2           3  Parveen Bhalla        3
# 3           4     Marlo Dugal       14
# 4           5     Kusum Bahri        6

# %%
students.shape
# Out:
# (25, 3)

# %%
jan_reg.head()
# Out:
#    student_id  course_id
# 0          23          1
# 1          15          5
# 2          18          6
# 3          23          4
# 4          16          9

# %%
feb_reg.head()
# Out:
#    student_id  course_id
# 0           3          5
# 1          16          7
# 2          12         10
# 3          12          1
# 4          14          9

# %%
#concat
reg = pd.concat([jan_reg,feb_reg],ignore_index=True)
reg
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3
# 25           3          5
# 26          16          7
# 27          12         10
# 28          12          1
# 29          14          9
# 30           7          7
# 31           7          2
# 32          16          3
# 33          17         10
# ...

# %%
#concat in horizantal
reg = pd.concat([jan_reg,feb_reg],axis=1)
reg
# Out:
#     student_id  course_id  student_id  course_id
# 0         23.0        1.0           3          5
# 1         15.0        5.0          16          7
# 2         18.0        6.0          12         10
# 3         23.0        4.0          12          1
# 4         16.0        9.0          14          9
# 5         18.0        1.0           7          7
# 6          1.0        1.0           7          2
# 7          7.0        8.0          16          3
# 8         22.0        3.0          17         10
# 9         15.0        1.0          11          8
# 10        19.0        4.0          14          6
# 11         1.0        6.0          12          5
# 12         7.0       10.0          12          7
# 13        11.0        7.0          18          8
# 14        13.0        3.0           1         10
# 15        24.0        4.0           1          9
# 16        21.0        1.0           2          5
# 17        16.0        5.0           7          6
# ...

# %%
#merge
df1 = reg.merge(students,on='student_id',how="inner")[["student_id","course_id","name"]]
df1
# Out:
#     student_id  course_id                name
# 0           23          1      Chhavi Lachman
# 1           15          5           Preet Sha
# 2           18          6     Fardeen Mahabir
# 3           23          4      Chhavi Lachman
# 4           16          9        Elias Dodiya
# 5           18          1     Fardeen Mahabir
# 6            1          1       Kailash Harjo
# 7            7          8        Tarun Thaker
# 8           22          3          Yash Sethi
# 9           15          1           Preet Sha
# 10          19          4        Qabeel Raman
# 11           1          6       Kailash Harjo
# 12           7         10        Tarun Thaker
# 13          11          7  David Mukhopadhyay
# 14          13          3      Munni Varghese
# 15          24          4        Radhika Suri
# 16          21          1          Seema Kota
# 17          16          5        Elias Dodiya
# 18          23          3      Chhavi Lachman
# ...

# %%
df1.merge(courses,on="course_id",how="inner")
# Out:
#     student_id  course_id                name       course_name  price
# 0           23          1      Chhavi Lachman            python   2499
# 1           15          5           Preet Sha           tableau   2499
# 2           18          6     Fardeen Mahabir          power bi   1899
# 3           23          4      Chhavi Lachman  machine learning   9999
# 4           16          9        Elias Dodiya            plotly    699
# 5           18          1     Fardeen Mahabir            python   2499
# 6            1          1       Kailash Harjo            python   2499
# 7            7          8        Tarun Thaker            pandas   1099
# 8           22          3          Yash Sethi     data analysis   4999
# 9           15          1           Preet Sha            python   2499
# 10          19          4        Qabeel Raman  machine learning   9999
# 11           1          6       Kailash Harjo          power bi   1899
# ...

# %%
reg.merge(courses,on="course_id",how="left")
# Out:
#     student_id  course_id       course_name  price
# 0           23          1            python   2499
# 1           15          5           tableau   2499
# 2           18          6          power bi   1899
# 3           23          4  machine learning   9999
# 4           16          9            plotly    699
# 5           18          1            python   2499
# 6            1          1            python   2499
# 7            7          8            pandas   1099
# 8           22          3     data analysis   4999
# 9           15          1            python   2499
# 10          19          4  machine learning   9999
# 11           1          6          power bi   1899
# 12           7         10           pyspark   2499
# 13          11          7          ms sxcel   1599
# 14          13          3     data analysis   4999
# 15          24          4  machine learning   9999
# 16          21          1            python   2499
# ...

# %%
reg.merge(courses,on="course_id",how="right")
# Out:
#     student_id  course_id       course_name  price
# 0         23.0          1            python   2499
# 1         18.0          1            python   2499
# 2          1.0          1            python   2499
# 3         15.0          1            python   2499
# 4         21.0          1            python   2499
# 5         25.0          1            python   2499
# 6         12.0          1            python   2499
# 7         14.0          1            python   2499
# 8         38.0          1            python   2499
# 9         19.0          2               sql   3499
# 10         7.0          2               sql   3499
# 11        22.0          3     data analysis   4999
# 12        13.0          3     data analysis   4999
# 13        23.0          3     data analysis   4999
# 14         3.0          3     data analysis   4999
# 15        16.0          3     data analysis   4999
# 16        23.0          4  machine learning   9999
# ...

# %%
reg.merge(courses,on="course_id",how="outer")
# Out:
#     student_id  course_id       course_name  price
# 0         23.0          1            python   2499
# 1         18.0          1            python   2499
# 2          1.0          1            python   2499
# 3         15.0          1            python   2499
# 4         21.0          1            python   2499
# 5         25.0          1            python   2499
# 6         12.0          1            python   2499
# 7         14.0          1            python   2499
# 8         38.0          1            python   2499
# 9         19.0          2               sql   3499
# 10         7.0          2               sql   3499
# 11        22.0          3     data analysis   4999
# 12        13.0          3     data analysis   4999
# 13        23.0          3     data analysis   4999
# 14         3.0          3     data analysis   4999
# 15        16.0          3     data analysis   4999
# 16        23.0          4  machine learning   9999
# ...

# %%
import matplotlib.pyplot as plt

# Sample Data
x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 50]

# Create a Line Plot
plt.plot(x, y, marker='o', linestyle='-', color='b',label='Sales',linewidth=1)

# Add Labels and Title
plt.xlabel("Days")
plt.ylabel("Revenue ($)")
plt.title("Sales Growth Over Days")

# Show Legend
plt.legend()

# Display the Plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample Data
import pandas as pd
data = {'Age': [22, 25, 47, 35, 30, 41, 50, 29, 40, 23],
        'Salary': [25000, 27000, 55000, 42000, 39000, 48000, 60000, 32000, 52000, 26000]}
df = pd.DataFrame(data)

# Create a Scatter Plot
sns.scatterplot(x='Age', y='Salary', data=df)

# Add Title
plt.title("Age vs Salary Distribution")

# Show Plot
plt.show()
