# %% [markdown]
# #Read mode

# %%
file=open("/content/sample.txt","r")
file
# Out:
# <_io.TextIOWrapper name='/content/sample.txt' mode='r' encoding='UTF-8'>

# %%
print(file.read(6))
# Out:
# python

# %%
print(file.read(6))
# Out:
#  is pr

# %%
print(file.read(6))
# Out:
# ogramm

# %%
file.write("xyz")
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-13-e3cc83abbf4d> in <cell line: 0>()
# ----> 1 file.write("xyz")
#
# UnsupportedOperation: not writable

# %%
print(file.read())
# Out:
# ing language

# %%
print(file.tell())
# Out:
# 30

# %%
print(file.read())

# %%
file.seek(0)
# Out:
# 0

# %%
print(file.tell())
# Out:
# 0

# %%
print(file.read())
# Out:
# python is programming language

# %%
print(file.tell())
# Out:
# 30

# %%
file.close()

# %%
file.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-f3fc120c03c1> in <cell line: 0>()
# ----> 1 file.read()
#
# ValueError: I/O operation on closed file.

# %%
file=open("/content/sample.txt","r")

# %%
print(file.readline())
# Out:
# Java is also programming language

# %%
print(file.readline())
# Out:
# datadreamers are planning to teach

# %%
print(file.readline())

# %%
for i in range(10):
  x=file.readline()
  if len(x)>0:
    print(x)
  else:
    break
# Out:
# python is programming language
#
# Java is also programming language
#
# datadreamers are planning to teach

# %%
for i in file.readlines():
  print(i)
# Out:
# python is programming language
#
# Java is also programming language
#
# datadreamers are planning to teach

# %% [markdown]
# #write mode

# %%
file1 = open("/content/sample.txt","w")

# %%
file1
# Out:
# <_io.TextIOWrapper name='/content/sample.txt' mode='w' encoding='UTF-8'>

# %%
file1.write("python")
# Out:
# 6

# %%
print(file1.tell())
# Out:
# 6

# %%
file1.write(" is programming language")
# Out:
# 24

# %%
print(file1.tell())
# Out:
# 30

# %%
file1.writelines(["\njava is also prog language\n","c is also prog language\n"])

# %%
file1.tell()
# Out:
# 82

# %% [markdown]
# #Append mode

# %%
file2 =open("/content/sample.txt","a")
file2.tell()
# Out:
# 82

# %%
file2.write("c++ is also prog language")
# Out:
# 25

# %%
file2.tell()
# Out:
# 107

# %%
file3 = open("/content/sample1.txt","a")

# %%
file3.tell()
# Out:
# 0

# %%
file3.write("python")
# Out:
# 6

# %%
file3.tell()
# Out:
# 6

# %% [markdown]
# #Exclusive write mode

# %%
file3 = open("/content/sample2.txt","x")
file3
# Out:
# <_io.TextIOWrapper name='/content/sample2.txt' mode='x' encoding='UTF-8'>

# %%
file3.write("python")
# Out:
# 6

# %%
file3.tell()
# Out:
# 6

# %% [markdown]
# #Read/Write mode

# %%
file4 = open("/content/sample.txt","r+")
print(file4.read())
# Out:
# python is programming language
# java is also prog language
# c is also prog language
# c++ is also prog language

# %%
file4.tell()
# Out:
# 107

# %%
file4.read()
# Out:
# ''

# %%
file4.write("\nr is also prog language")
# Out:
# 24

# %%
file4.tell()
# Out:
# 131

# %%
file4.seek(0)
# Out:
# 0

# %%
file4.write("java")
# Out:
# 4

# %%
file4.tell()
# Out:
# 4

# %% [markdown]
# #Write/Read Mode

# %%
file5 =open("/content/sample.txt","w+")
file5
# Out:
# <_io.TextIOWrapper name='/content/sample.txt' mode='w+' encoding='UTF-8'>

# %%
file5.write("python is prog language")
# Out:
# 23

# %%
file5.tell()
# Out:
# 23

# %%
file5.seek(0)
# Out:
# 0

# %%
file5.read(6)
# Out:
# 'python'

# %% [markdown]
# #Append/Read mode

# %%
file6 = open("/content/sample.txt","a+")
file6.tell()
# Out:
# 23

# %%
file6.write(" c++ is also prog langauge")
# Out:
# 26

# %%
file6.tell()
# Out:
# 49

# %%
file6.seek(3)
# Out:
# 3

# %%
file6.read()
# Out:
# 'hon is prog language c++ is also prog langauge'

# %%
file6.close()

# %% [markdown]
# #With keyword

# %%
with open("/content/sample.txt","r") as f:
  print(f.read())
# Out:
# python is prog language c++ is also prog langauge
