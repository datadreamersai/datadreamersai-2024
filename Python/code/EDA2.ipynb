# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/imdb_top_1000.csv")
df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
df.isnull()
# Out:
#      Poster_Link  Series_Title  Released_Year  Certificate  Runtime  Genre  \
# 0          False         False          False        False    False  False
# 1          False         False          False        False    False  False
# 2          False         False          False        False    False  False
# 3          False         False          False        False    False  False
# 4          False         False          False        False    False  False
# ..           ...           ...            ...          ...      ...    ...
# 995        False         False          False        False    False  False
# 996        False         False          False        False    False  False
# 997        False         False          False        False    False  False
# 998        False         False          False         True    False  False
# 999        False         False          False         True    False  False
#
# ...

# %%
df.isnull().sum(axis=0)
# Out:
# Poster_Link        0
# Series_Title       0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Overview           0
# Meta_score       157
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %%
df.Certificate.mode().values[0]
# Out:
# 'U'

# %%
df.Certificate.fillna(df.Certificate.mode().values[0],inplace=True)

# %%
df.Certificate
# Out:
# 0           A
# 1           A
# 2          UA
# 3           A
# 4           U
#         ...
# 995         A
# 996         G
# 997    Passed
# 998       NaN
# 999       NaN
# Name: Certificate, Length: 1000, dtype: object

# %%
df.isnull().sum(axis=0)
# Out:
# Poster_Link        0
# Series_Title       0
# Released_Year      0
# Certificate        0
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Overview           0
# Meta_score       157
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %%
def fillnan(ind,row):
  if (ind ==998):

    return "U"
  elif (ind==999):

    return "Not_Available"
for ind, row in df.iterrows():
  if pd.isnull(row["Certificate"]):
      print(fillnan(ind,row))
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# U
# Not_Available

# %%
count=0
for ind, row in df.iterrows():
  if count<10:
    print(ind, row["Certificate"])
    count+=1
  else:
    break
# Out:
# 0 A
# 1 A
# 2 UA
# 3 A
# 4 U
# 5 U
# 6 A
# 7 A
# 8 UA
# 9 A

# %%
df.notnull()
# Out:
#      Poster_Link  Series_Title  Released_Year  Certificate  Runtime  Genre  \
# 0           True          True           True         True     True   True
# 1           True          True           True         True     True   True
# 2           True          True           True         True     True   True
# 3           True          True           True         True     True   True
# 4           True          True           True         True     True   True
# ..           ...           ...            ...          ...      ...    ...
# 995         True          True           True         True     True   True
# 996         True          True           True         True     True   True
# 997         True          True           True         True     True   True
# 998         True          True           True        False     True   True
# 999         True          True           True        False     True   True
#
# ...

# %%
df.notnull().sum(axis=0)
# Out:
# Poster_Link      1000
# Series_Title     1000
# Released_Year    1000
# Certificate       899
# Runtime          1000
# Genre            1000
# IMDB_Rating      1000
# Overview         1000
# Meta_score        843
# Director         1000
# Star1            1000
# Star2            1000
# Star3            1000
# Star4            1000
# No_of_Votes      1000
# Gross             831
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (714, 16)

# %%
sample_dict={
    "A":[1,2,np.nan],
    "B":[2,1,np.nan],
    "C":[23,45,np.nan],
    "D":[np.nan,24,np.nan]
}

sample_df = pd.DataFrame(sample_dict)
sample_df
# Out:
#      A    B     C     D
# 0  1.0  2.0  23.0   NaN
# 1  2.0  1.0  45.0  24.0
# 2  NaN  NaN   NaN   NaN

# %%
sample_df.dropna(how="all")
# Out:
#      A    B     C     D
# 0  1.0  2.0  23.0   NaN
# 1  2.0  1.0  45.0  24.0

# %%
sample_df.dropna(how="any")# == sample_df.dropna()
# Out:
#      A    B     C     D
# 1  2.0  1.0  45.0  24.0

# %%
sample_dict={
    "A":[1,2,np.nan],
    "B":[2,1,np.nan],
    "C":[23,np.nan,np.nan],
    "D":[np.nan,24,np.nan]
}
sample_df = pd.DataFrame(sample_dict)
sample_df
# Out:
#      A    B     C     D
# 0  1.0  2.0  23.0   NaN
# 1  2.0  1.0   NaN  24.0
# 2  NaN  NaN   NaN   NaN

# %%
sample_df.dropna(subset=["B","C"],how="all")
# Out:
#      A    B     C     D
# 0  1.0  2.0  23.0   NaN
# 1  2.0  1.0   NaN  24.0

# %%
l=[[1,2,3,4],[5,6,3,8],[5,6,8,9],[1,2,3,4]]

dup_df = pd.DataFrame(l,columns=["num1","num2","num3","num4"])
dup_df
# Out:
#    num1  num2  num3  num4
# 0     1     2     3     4
# 1     5     6     3     8
# 2     5     6     8     9
# 3     1     2     3     4

# %%
dup_df.drop_duplicates(keep="last")
# Out:
#    num1  num2  num3  num4
# 1     5     6     3     8
# 2     5     6     8     9
# 3     1     2     3     4

# %%
dup_df.drop_duplicates(keep="last")
# Out:
#    num1  num2  num3  num4
# 1     5     6     3     8
# 2     5     6     8     9
# 3     1     2     3     4

# %%
df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
df.drop(columns=["Poster_Link","Overview"],inplace=True)

# %%
df.head()
# Out:
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  Meta_score              Director  \
# 0                 Drama          9.3        80.0        Frank Darabont
# 1          Crime, Drama          9.2       100.0  Francis Ford Coppola
# 2  Action, Crime, Drama          9.0        84.0     Christopher Nolan
# 3          Crime, Drama          9.0        90.0  Francis Ford Coppola
# 4          Crime, Drama          9.0        96.0          Sidney Lumet
#
#             Star1           Star2          Star3           Star4  No_of_Votes  \
# ...

# %%
df.drop(index=0,inplace=True)

# %%
df.head()
# Out:
#                                     Series_Title Released_Year Certificate  \
# 2                                The Dark Knight          2008          UA
# 4                                   12 Angry Men          1957           U
# 5  The Lord of the Rings: The Return of the King          2003           U
# 6                                   Pulp Fiction          1994           A
# 7                               Schindler's List          1993           A
#
#    Runtime                      Genre  IMDB_Rating  Meta_score  \
# 2  152 min       Action, Crime, Drama          9.0        84.0
# 4   96 min               Crime, Drama          9.0        96.0
# 5  201 min   Action, Adventure, Drama          8.9        94.0
# 6  154 min               Crime, Drama          8.9        94.0
# 7  195 min  Biography, Drama, History          8.9        94.0
#
#             Director           Star1            Star2              Star3  \
# ...

# %%
df.set_index("Series_Title",inplace=True)
df.head()
# Out:
#                                               Released_Year Certificate  \
# Series_Title
# The Dark Knight                                        2008          UA
# 12 Angry Men                                           1957           U
# The Lord of the Rings: The Return of the King          2003           U
# Pulp Fiction                                           1994           A
# Schindler's List                                       1993           A
#
#                                                Runtime  \
# Series_Title
# The Dark Knight                                152 min
# 12 Angry Men                                    96 min
# The Lord of the Rings: The Return of the King  201 min
# Pulp Fiction                                   154 min
# Schindler's List                               195 min
#
#                                                                    Genre  \
# Series_Title
# The Dark Knight                                     Action, Crime, Drama
# ...

# %%
df.reset_index()
# Out:
#                                       Series_Title Released_Year Certificate  \
# 0                                  The Dark Knight          2008          UA
# 1                                     12 Angry Men          1957           U
# 2    The Lord of the Rings: The Return of the King          2003           U
# 3                                     Pulp Fiction          1994           A
# 4                                 Schindler's List          1993           A
# ..                                             ...           ...         ...
# 706                                   Giù la testa          1971          PG
# 707                                 Kelly's Heroes          1970          GP
# 708                                The Jungle Book          1967           U
# 709                             A Hard Day's Night          1964           U
# 710                          From Here to Eternity          1953      Passed
#
# ...
